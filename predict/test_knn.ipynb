# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
import math
import matplotlib

# %%
get_weight = {
    "BW":61.2,
    "LHW":93.0,
    "WW":77.1,
    "HW":120.2,
    "LW":70.3,
    "MW":83.9,
    "FW":65.8,
    "FlyW":56.7,
    "W_FW":65.8,
    "W_SW":52.2,
    "W_FlyW":56.7,
    "W_BW":61.2
}

# %%
fm_bd_all=pd.read_csv('fights_all.csv')

fm_bd_model = fm_bd_all.copy()
fm_bd_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5123 entries, 0 to 5122
# Columns: 198 entries, Unnamed: 0 to B_Method_Code
# dtypes: float64(176), int64(2), object(20)
# memory usage: 7.7+ MB

# %%
fm_bd_model.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>F_Bout_URL</th>
#       <th>T_Bout_URL</th>
#       <th>Event_Date</th>
#       <th>T_Event_URL</th>
#       <th>FO</th>
#       <th>F1_URL</th>
#       <th>F1_T_ID</th>
#       <th>F1_BFO_URL</th>
#       <th>F2_URL</th>
#       <th>...</th>
#       <th>F1_Open</th>
#       <th>F1_Close_Best</th>
#       <th>F1_Close_Worst</th>
#       <th>F2_Open</th>
#       <th>F2_Close_Best</th>
#       <th>F2_Close_Worst</th>
#       <th>B_F1_Bool_Result</th>
#       <th>B_WClass</th>
#       <th>B_Title</th>
#       <th>B_Method_Code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>http://www.fightmetric.com/fight-details/498e7...</td>
#       <td>https://www.tapology.com/fightcenter/bouts/393...</td>
#       <td>2018-12-29</td>
#       <td>https://www.tapology.com/fightcenter/events/49...</td>
#       <td>Fighter_2</td>
#       <td>http://www.fightmetric.com/fighter-details/3a3...</td>
#       <td>38718-douglas-dsilva</td>
#       <td>https://www.bestfightodds.com/fighters/Douglas...</td>
#       <td>http://www.fightmetric.com/fighter-details/d66...</td>
#       <td>...</td>
#       <td>2.100000</td>
#       <td>3.990000</td>
#       <td>3.450000</td>
#       <td>1.769231</td>
#       <td>1.30030</td>
#       <td>1.253165</td>
#       <td>0</td>
#       <td>BW</td>
#       <td>0</td>
#       <td>TKO</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>http://www.fightmetric.com/fight-details/ceaae...</td>
#       <td>https://www.tapology.com/fightcenter/bouts/387...</td>
#       <td>2018-12-29</td>
#       <td>https://www.tapology.com/fightcenter/events/49...</td>
#       <td>Fighter_1</td>
#       <td>http://www.fightmetric.com/fighter-details/07f...</td>
#       <td>jon-jones-bones</td>
#       <td>https://www.bestfightodds.com/fighters/Jon-Jon...</td>
#       <td>http://www.fightmetric.com/fighter-details/3c6...</td>
#       <td>...</td>
#       <td>1.500000</td>
#       <td>1.625000</td>
#       <td>1.294118</td>
#       <td>2.700000</td>
#       <td>3.65000</td>
#       <td>2.250000</td>
#       <td>1</td>
#       <td>LHW</td>
#       <td>1</td>
#       <td>TKO</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td